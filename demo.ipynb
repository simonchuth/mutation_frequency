# %%
import pandas as pd
from src.plot_gene import plot_mutation_frequency, plot_cancer_type_freq
import matplotlib.pyplot as plt

# %%
datapath = 'sample_data/pten.csv'
df = pd.read_csv(datapath)
df
# Out:
#      GENE_NAME   ACCESSION_NUMBER   GENE_CDS_LENGTH   HGNC_ID  \
# 0         PTEN  ENST00000371953.7              1212      9588
# 1         PTEN  ENST00000371953.7              1212      9588
# 2         PTEN  ENST00000371953.7              1212      9588
# 3         PTEN  ENST00000371953.7              1212      9588
# 4         PTEN  ENST00000371953.7              1212      9588
# ...        ...                ...               ...       ...
# 2733      PTEN  ENST00000371953.7              1212      9588
# 2734      PTEN  ENST00000371953.7              1212      9588
# 2735      PTEN  ENST00000371953.7              1212      9588
# 2736      PTEN  ENST00000371953.7              1212      9588
# 2737      PTEN  ENST00000371953.7              1212      9588
#
#                 PRIMARY_SITE  MUTATION_CDS  MUTATION_AA  Site
# 0                soft_tissue        c.5C>T        p.T2I     2
# 1                endometrium        c.7G>T        p.A3S     3
# 2            large_intestine        c.8C>A        p.A3D     3
# 3            large_intestine        c.8C>A        p.A3D     3
# 4     central_nervous_system       c.13A>C        p.I5L     5
# ...                      ...           ...          ...   ...
# 2733  central_nervous_system     c.1192A>T      p.T398S   398
# 2734                   ovary           c.?      p.T398S   398
# 2735                    lung     c.1197A>T      p.Q399H   399
# 2736  central_nervous_system     c.1202C>T      p.T401I   401
# 2737             soft_tissue     c.1202C>T      p.T401I   401
#
# [2738 rows x 8 columns]

# %%
sites = df.Site.values
size = 403 
gene_name = 'PTEN'
mutation_type = 'Missense'

# %%
plot_mutation_frequency(sites, size, gene_name=gene_name, mutation_type=mutation_type)
plt.savefig('pten_mut_frequency.jpg')

# %%
cancer_list = df[' PRIMARY_SITE'].value_counts()

# %%
plot_cancer_type_freq(cancer_list, gene_name=gene_name, mutation_type=mutation_type)
plt.savefig('pten_cancer_frequency.jpg')
